# %% [markdown]
# # Executable EODigitalTwins Example
# This starter notebook confirms that executable notebook content builds correctly.

# %%
components = ["Earth observation data", "models", "services", "applications"]
for number, component in enumerate(components, start=1):
    print(f"{number}. {component}")
